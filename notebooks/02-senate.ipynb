# %% [markdown]
# # Senate
#
# > The Senate is the upper chamber of Congress, composed of 24 senators that serve 6-year terms.

# %%
# | default_exp senate
# | export
import datetime
import re
import black
import requests

from pydantic import BaseModel
from typing import Dict, Optional, List
from bs4 import BeautifulSoup, NavigableString
from itertools import islice, chain
from urllib.parse import urljoin, urlencode, parse_qsl, urlparse
from more_itertools import split_when, grouper
from pathlib import Path
from diskcache import Cache

from legisph.website import Website, NotFoundError, ServerError, Link
from legisph.core import logger

# %% [markdown]
# ## Observations
#
# * The Senate website uses `<blockquote>` tags very liberally, without it actually meaning a quote.
# * Some of the tags are unclosed. [Changing the HTML parser to `html5lib`](https://www.crummy.com/software/BeautifulSoup/bs4/doc/#differences-between-parsers) for `BeautifulSoup` worked to solve this issue, as it attempts to parse the same way browsers do.
# * The votes table is partcularly problematic where they add a weird "Abstain" header but only if particular senators have abstained.
# * Sometimes, the senator names were in a comma separated list, but sometimes they were in a certain layout with blockquotes and break tags.

# %% [markdown]
# ## Senate Bills
#
# We create a method to extract any bill's metadata based on the congress number and bill number. I chose this not for any reason but that this bill had the most details of any I had encountered.

# %%
# | export
class Senator(BaseModel):
    """A member of the Senate"""

    name: str

    def __hash__(self):
        return hash(self.name)

    def __eq__(self, other):
        if not isinstance(other, Senator):
            return False
        return self.name == other.name

# %%
assert Senator(name="Juan de la Cruz") == Senator(name="Juan de la Cruz")
assert Senator(name="Juan de la Cruz") != Senator(name="Jane de la Cruz")

# %%
# | export
class SenateCommittee(BaseModel):
    """A committee in the Senate"""

    name: str
    congress: int

    def __hash__(self):
        return hash(self.name)

    def __eq__(self, other):
        if not isinstance(other, SenateCommittee):
            return False
        return self.name == other.name

# %%
assert SenateCommittee(name="Ways and Means", congress=18) == SenateCommittee(
    name="Ways and Means", congress=19
)
assert SenateCommittee(name="Finance", congress=19) != SenateCommittee(
    name="Ways and Means", congress=19
)

# %%
# | export
class SenateBill(BaseModel):
    """
    These are general measures, which if passed upon, may become laws.
    A bill is prefixed with S., followed by a number assigned the measure based
    on the order in which it is introduced. The vast majority of legislative
    proposals recommendations dealing with the economy, increasing penalties
    for certain crimes, regulation on commerce and trade, etc., are drafted in
    the form of bills. They also include budgetary appropriation of the
    government and many others. When passed by both chambers in identical
    form and signed by the President or repassed by Congress over a presidential
    veto, they become laws.

    [Source](http://legacy.senate.gov.ph/about/legpro.asp)
    """

    class SenateBillStatus(BaseModel):
        date: datetime.date
        item: str

    class FloorActivity(BaseModel):
        date: datetime.date
        parliamentary_status: str
        senators: Optional[List[Senator]]

    class Subject(BaseModel):
        name: str

    class Vote(BaseModel):
        type: str
        date: datetime.date
        tally: Dict[str, List[Senator]]

    url: str
    congress: int
    billno: str
    congress_text: str
    billno_text: str
    title: str
    long_title: str
    filing_date: datetime.date
    filers: Optional[List[Senator]]
    links: Optional[List[Link]]
    scope: str
    legislative_status: SenateBillStatus
    subjects: Optional[List[Subject]]
    primary_committee: Optional[List[SenateCommittee]]
    secondary_committee: Optional[List[SenateCommittee]]
    committee_reports: Optional[List[Link]]
    sponsors: Optional[List[Senator]]
    cosponsors: Optional[List[Senator]]
    document_certification: Optional[str]
    floor_activity: Optional[List[FloorActivity]]
    votes: Optional[List[Vote]]
    legislative_history: List[SenateBillStatus]

    def __str__(self):
        return f"[{self.billno}] {self.title}"

    def __repr__(self):
        return black.format_str(super().__repr__(), mode=black.Mode())

# %%
# | export
class SenateWebsite(Website):
    """
    The Senate Website, accessible at [senate.gov.ph](https://senate.gov.ph/).
    """

    def __init__(self, cache_dir=Path(".cache/senate"), **kwargs):
        super().__init__("senate_requests", cache_dir=cache_dir, **kwargs)
        self.cache = Cache(str(cache_dir / "senate_cache"))

    def fetch_bill(self, congress: int, billno: str):
        """Retrieve a SenateBill from the website."""

        # Initial parameters
        url = "http://legacy.senate.gov.ph/lis/bill_res.aspx"
        params = {"q": billno, "congress": congress}

        # Initial call to get form session parameters
        resp = self.session.get(url=url, params=params)
        html = BeautifulSoup(resp.text, features="html5lib")

        # Handle error cases
        content_str = html.find("td", {"id": "content"}).text.strip()
        resource = f"Senate Bill {billno} in Congress {congress}"
        match content_str:
            case "Not found.":
                raise NotFoundError(f"{resource} not found", resource)
            case "An error has occured. Exception has been logged.":
                raise ServerError(f"Internal Error for {resource}", resource)

        # Access the form data
        form = html.find(name="form", attrs={"name": "form1"})
        inputs = form.find_all(name="input")
        data = {i["id"]: i.attrs.get("value", "") for i in inputs}

        # Set to fetch all information
        data.update({"__EVENTTARGET": "lbAll", "__EVENTARGUMENT": ""})

        # Fetch bill information
        resp = self.session.post(url=url, params=params, data=data)

        # Break into parts
        html = BeautifulSoup(resp.text, features="html5lib")
        content = html.find("td", attrs={"id": "content"})
        title = list(islice(content.children, 5))
        data = {
            item.find_previous().text.strip(): item
            for item in content.find_all("blockquote", recursive=False)
        }

        # Parse through complex votes table
        votes = data.get("Vote(s)")
        if votes:

            def parse_tally(votes):
                tally = {}
                for vote in votes:
                    elems = vote.find_all("td")
                    tally = tally | {
                        vote.text.strip(): (
                            [
                                Senator(name=voter.text.strip())
                                for voter in voters.find("blockquote").children
                                if voter.text.strip() != ""
                            ]
                            if vote.text.strip() != "Abstained"
                            else [
                                Senator(name=f"{senator[0]}, {senator[1]}")
                                for senator in grouper(
                                    voters.text.strip().split(", "), 2
                                )
                            ]
                        )
                        for vote, voters in zip(
                            elems[0 : (len(elems) // 2)],
                            elems[len(elems) // 2 : len(elems) + 1],
                        )
                    }
                return tally

            elems = (e for e in votes.children if not isinstance(e, NavigableString))
            votes = list(split_when(elems, lambda _, y: y.name == "blockquote"))
            votes = [
                SenateBill.Vote(
                    type=vote[0].text.split("(")[0].strip(),
                    date=datetime.datetime.strptime(
                        vote[0].text.split("(")[1].replace(")", ""), "%m/%d/%Y"
                    ),
                    tally=parse_tally(vote[1:]),
                )
                for vote in votes
            ]

        # Parse subtitle
        subtitle = title[4].text.strip()
        subtitle = subtitle.split("Filed on ")[1].split(" by")

        # Construct Senate Bill
        bill = SenateBill(
            url=url + "?" + urlencode(params),
            congress=congress,
            billno=billno,
            congress_text=title[0].text.strip(),
            billno_text=title[2].text.strip(),
            title=content.find("div", class_="lis_doctitle").text.strip(),
            long_title=data["Long title"].text.strip(),
            filing_date=datetime.datetime.strptime(subtitle[0], "%B %d, %Y"),
            filers=(
                [
                    Senator(name=f"{s[0]}, {s[1]}".strip())
                    for s in grouper(subtitle[1].split(", "), 2)
                ]
                if subtitle[1] != ""
                else None
            ),
            links=(
                [
                    Link(url=urljoin(url, t["href"]), name=t.text.strip())
                    for t in links.find_all("a")
                ]
                if (links := content.find("div", id="lis_download"))
                else None
            ),
            scope=data["Scope"].text.strip(),
            legislative_status=SenateBill.SenateBillStatus(
                date=datetime.datetime.strptime(
                    re.findall(
                        r"\((.+)\)", (s := data["Legislative status"].text.strip())
                    )[0],
                    "%m/%d/%Y",
                ),
                item=re.findall(r"(.+) \(", s)[0],
            ),
            subjects=(
                [
                    SenateBill.Subject(name=subject.text)
                    for subject in subjects
                    if subject.text != ""
                ]
                if (subjects := data.get("Subject(s)"))
                else None
            ),
            primary_committee=(
                [
                    SenateCommittee(name=committee.text, congress=congress)
                    for committee in committees.children
                    if committee.text != ""
                ]
                if (committees := data.get("Primary committee"))
                else None
            ),
            secondary_committee=(
                [
                    SenateCommittee(name=committee.text, congress=congress)
                    for committee in committees.children
                    if committee.text != ""
                ]
                if (committees := data.get("Secondary committee"))
                else None
            ),
            committee_reports=(
                [
                    Link(url=urljoin(url, report["href"]), name=report.text)
                    for report in reports.find_all("a")
                ]
                if (reports := data.get("Committee report"))
                else None
            ),
            sponsors=(
                [
                    Senator(name=f"{senator[0]}, {senator[1]}")
                    for senator in grouper(sponsors.text.split(", "), 2)
                ]
                if (sponsors := data.get("Sponsor(s)"))
                else None
            ),
            cosponsors=(
                [
                    Senator(name=f"{senator[0]}, {senator[1]}")
                    for senator in grouper(cosponsors.text.split(", "), 2)
                ]
                if (cosponsors := data.get("Co-sponsor(s)"))
                else None
            ),
            document_certification=(
                certification.text
                if (certification := data.get("Document certification"))
                else None
            ),
            floor_activity=(
                [
                    SenateBill.FloorActivity(
                        date=datetime.datetime.strptime(
                            cols[0].text.strip(), "%m/%d/%Y"
                        ),
                        parliamentary_status=cols[1].text.strip(),
                        senators=(
                            [
                                Senator(name=senator.text.strip())
                                for senator in cols[2].children
                                if senator.text.strip() != ""
                            ]
                            if len(list(cols[2].children)) > 0
                            else None
                        ),
                    )
                    for cols in [
                        row.find_all("td") for row in floor_activity.find_all("tr")
                    ][1:]
                ]
                if (floor_activity := data.get("Floor activity"))
                else None
            ),
            votes=votes,
            legislative_history=[
                SenateBill.SenateBillStatus(
                    date=datetime.datetime.strptime(row[0].text.strip(), "%m/%d/%Y"),
                    item=row[1].text.strip(),
                )
                for row in (
                    row.find_all("td")
                    for row in data["Legislative History"].find_all("tr")
                )
                if len(row) == 2
            ],
        )

        return bill

    def generate_bills(self, congress: int):
        """
        Generator function that eventually produces all bills from a congress.
        """

        page = 1
        while True:
            # Fetch and parse the page
            resp = self.session.get(
                url="http://legacy.senate.gov.ph/lis/leg_sys.aspx",
                params={"type": "bill", "congress": congress, "p": page},
            )
            html = BeautifulSoup(resp.text, features="html5lib")
            bills = [
                dict(parse_qsl(urlparse(a["href"]).query))
                for a in html.find("div", class_="alight").find_all("a")
            ]
            # Extract and yield each bill, handle exceptions
            for b in bills:
                try:
                    yield self.fetch_bill(congress=b["congress"], billno=b["q"])
                except (NotFoundError, ServerError) as exc:
                    logger.error(exc.message)
                    yield exc
                except Exception as exc:
                    logger.error(f"Exception at {b['q']}, congress {b['congress']}")
                    raise exc
            # Try to find the next button and advance if found
            if html.find("a", string="Next\n"):
                page += 1
            else:
                break

    def fetch_bills(self, congress: int):
        return list(self.generate_bills(congress))

    def get_congresses(self):
        resp = requests.get(
            "https://legacy.senate.gov.ph/lis/leg_sys.aspx",
            headers=self.session.headers,
        )
        html = BeautifulSoup(resp.content, features="html5lib")
        congresses = [
            int(dict(parse_qsl(link["href"].split("?")[1]))["congress"])
            for link in html.find(id="div_ChangeCongress").find("ul").find_all("a")
        ]
        return congresses

    def fetch_all_bills(self):
        """
        Generator function that returns all bills from all congresses.
        """
        congresses = self.get_congresses()
        return list(chain(*(self.fetch_bills(congress) for congress in congresses)))

# %% [markdown]
# The Senate Website caches any HTTP requests to a folder `.cache/senate`. We can fetch individual bills data, such as the SBN-2332 in the 18th congress, which is quite complex:

# %%
senate = SenateWebsite()
senate.fetch_bill(18, "SBN-2332")
# Out:
# SenateBill(
#     url="http://legacy.senate.gov.ph/lis/bill_res.aspx?q=SBN-2332&congress=18",
#     congress=18,
#     billno="SBN-2332",
#     congress_text="18th Congress",
#     billno_text="Senate Bill No. 2332",
#     title="STATUTORY RAPE (INCREASING THE AGE)",
#     long_title="AN ACT INCREASING THE AGE FOR DETERMINING STATUTORY RAPE AND OTHER ACTS OF SEXUAL ABUSE AND EXPLOITATION TO PROTECT CHILDREN, AMENDING FOR THIS PURPOSE ACT NO. 3815, AS AMENDED, ALSO KNOWN AS THE REVISED PENAL CODE, REPUBLIC ACT NO. 8353, ALSO KNOWN AS THE ANTI-RAPE LAW OF 1997, AND REPUBLIC ACT NO. 7610, ALSO KNOWN AS THE SPECIAL PROTECTION OF CHILDREN AGAINST ABUSE, EXPLOITATION AND DISCRIMINATION ACT",
#     filing_date=datetime.date(2021, 7, 26),
#     filers=[
#         Senator(name="Hontiveros, Risa"),
#         Senator(name='Zubiri, Juan Miguel "Migz" F.'),
#         Senator(name="De Lima, Leila M."),
#         Senator(name="Gatchalian, Win"),
#         Senator(name="Binay, Maria Lourdes Nancy S."),
#         Senator(name="Marcos, Imee R."),
#         Senator(name="Revilla Jr., Ramon Bong"),
#         Senator(name="Gordon, Richard J."),
#         Senator(name='Pangilinan, Francis "Kiko" N.'),
#         Senator(name="Villanueva, Joel"),
#         Senator(name="Cayetano, Pia S."),
#         Senator(name="Poe, Grace"),
#     ],
#     links=[
#         Link(
#             url="http://legacy.senate.gov.ph/lisdata/3582432274!.pdf",
#             name="SBN-2332 (Per Ctte. Rpt. No. 279)",
#         ),
#         Link(
#             url="http://legacy.senate.gov.ph/lisdata/3582432777!.pdf",
#             name="SBN-2332 (Third Reading Copy)",
#         ),
#         Link(
#             url="http://legacy.senate.gov.ph/republic_acts/ra%2011648.pdf",
#             name="Republic Act No. 11648",
#         ),
#     ],
#     scope="National",
#     legislative_status=SenateBillStatus(
#         date=datetime.date(2022, 3, 4),
#         item="Approved by the President of the Philippines",
#     ),
#     subjects=[
#         Subject(name="Statutory Rape"),
#         Subject(name="Child Abuse, Exploitation and Discrimination Act (R.A.No. 7610)"),
#         Subject(name="Revised Penal Code (R.A.No. 3815)"),
#         Subject(name="Anti-Rape"),
#     ],
#     primary_committee=[SenateCommittee(name="Justice and Human Rights", congress=18)],
#     secondary_committee=[
#         SenateCommittee(
#             name="Women, Children, Family Relations and Gender Equality", congress=18
#         )
#     ],
#     committee_reports=[
#         Link(
#             url="http://legacy.senate.gov.ph/lis/committee_rpt.aspx?congress=18&q=279",
#             name="No. 279 - Statutory Rape",
#         )
#     ],
#     sponsors=[Senator(name="Gordon, Richard J.")],
#     cosponsors=None,
#     document_certification="No Certification",
#     floor_activity=[
#         FloorActivity(
#             date=datetime.date(2021, 8, 25),
#             parliamentary_status="Co-Sponsorship Speech",
#             senators=[
#                 Senator(name='Zubiri, Juan Miguel "Migz" F.'),
#                 Senator(name="Hontiveros, Risa"),
#                 Senator(name="Villanueva, Joel"),
#                 Senator(name="Cayetano, Pia S."),
#                 Senator(name="Binay, Maria Lourdes Nancy S."),
#                 Senator(name="Revilla Jr., Ramon Bong"),
#                 Senator(name="Gatchalian, Win"),
#             ],
#         ),
#         FloorActivity(
#             date=datetime.date(2021, 8, 25),
#             parliamentary_status="Sponsorship Speech",
#             senators=[Senator(name="Gordon, Richard J.")],
#         ),
#         FloorActivity(
#             date=datetime.date(2021, 9, 20),
#             parliamentary_status="Interpellation",
#             senators=[
#                 Senator(name="Hontiveros, Risa"),
#                 Senator(name="Cayetano, Pia S."),
#                 Senator(name='Zubiri, Juan Miguel "Migz" F.'),
#                 Senator(name='Lacson, Panfilo "Ping" M.'),
#                 Senator(name="Sotto III, Vicente C."),
#                 Senator(name="Drilon, Franklin M."),
#                 Senator(name='Pangilinan, Francis "Kiko" N.'),
#                 Senator(name="Angara, Sonny"),
#             ],
#         ),
#         FloorActivity(
#             date=datetime.date(2021, 9, 21),
#             parliamentary_status="Period of Individual Amendments",
#             senators=None,
#         ),
#         FloorActivity(
#             date=datetime.date(2021, 9, 21),
#             parliamentary_status="Period of Interpellation Closed",
#             senators=None,
#         ),
#         FloorActivity(
#             date=datetime.date(2021, 9, 21),
#             parliamentary_status="Period of Individual Amendments Closed",
#             senators=None,
#         ),
#         FloorActivity(
#             date=datetime.date(2021, 12, 15),
#             parliamentary_status="Sponsorship Speech on the Conference Committee Report",
#             senators=[Senator(name='Zubiri, Juan Miguel "Migz" F.')],
#         ),
#     ],
#     votes=[
#         Vote(
#             type="Third Reading",
#             date=datetime.date(2021, 9, 27),
#             tally={
#                 "Voted Yes": [
#                     Senator(name="Angara, Sonny"),
#                     Senator(name="Binay, Maria Lourdes Nancy S."),
#                     Senator(name="Cayetano, Pia S."),
#                     Senator(name='Dela Rosa, Ronald "Bato"'),
#                     Senator(name="Drilon, Franklin M."),
#                     Senator(name="Gatchalian, Win"),
#                     Senator(name="Go, Christopher Lawrence T."),
#                     Senator(name="Gordon, Richard J."),
#                     Senator(name="Hontiveros, Risa"),
#                     Senator(name='Lacson, Panfilo "Ping" M.'),
#                     Senator(name='Lapid, Manuel "Lito" M.'),
#                     Senator(name="Marcos, Imee R."),
#                     Senator(name='Pacquiao, Emmanuel "Manny" D.'),
#                     Senator(name='Pangilinan, Francis "Kiko" N.'),
#                     Senator(name="Poe, Grace"),
#                     Senator(name="Recto, Ralph G."),
#                     Senator(name="Revilla Jr., Ramon Bong"),
#                     Senator(name="Sotto III, Vicente C."),
#                     Senator(name='Tolentino, Francis "Tol" N.'),
#                     Senator(name="Villanueva, Joel"),
#                     Senator(name="Villar, Cynthia A."),
#                     Senator(name='Zubiri, Juan Miguel "Migz" F.'),
#                 ],
#                 "Voted No": [],
#                 "Abstained": [Senator(name='Pimentel, Aquilino "Koko" III')],
#             },
#         )
#     ],
#     legislative_history=[
#         SenateBillStatus(
#             date=datetime.date(2021, 7, 26),
#             item='Prepared and submitted jointly by the Committees on JUSTICE AND HUMAN RIGHTS and WOMEN, CHILDREN, FAMILY RELATIONS AND GENDER EQUALITY with Senators RISA HONTIVEROS, JUAN MIGUEL "MIGZ" F. ZUBIRI, LEILA M. DE LIMA, WIN GATCHALIAN, MARIA LOURDES NANCY S. BINAY, IMEE R. MARCOS, RAMON BONG REVILLA JR. and RICHARD J. GORDON as authors  per Committee Report No. 279, recommending its approval in substitution of S. Nos. 163, 305, 622, 739, 762, 774, 1258 and 1853;',
#         ),
#         SenateBillStatus(
#             date=datetime.date(2021, 8, 2),
#             item="Committee Report Calendared for Ordinary Business;",
#         ),
#         SenateBillStatus(
#             date=datetime.date(2021, 8, 2), item="Sponsor: Senator RICHARD J. GORDON;"
#         ),
#         SenateBillStatus(
#             date=datetime.date(2021, 8, 4),
#             item='Letter from Senator FRANCIS "KIKO" N. PANGILINAN requesting to be made co-author of SBN-2332, received by LBIS;',
#         ),
#         SenateBillStatus(
#             date=datetime.date(2021, 8, 25),
#             item="Transferred from the Calendar for Ordinary Business to the Calendar for  Special Order;",
#         ),
#         SenateBillStatus(
#             date=datetime.date(2021, 8, 25),
#             item="Sponsorship speech delivered by Senator RICHARD J. GORDON;",
#         ),
#         SenateBillStatus(
#             date=datetime.date(2021, 8, 25),
#             item='Co-sponsorship speech of Senators JUAN MIGUEL "MIGZ" F. ZUBIRI, RISA HONTIVEROS, JOEL VILLANUEVA, PIA S. CAYETANO, MARIA LOURDES NANCY S. BINAY, RAMON BONG REVILLA JR. and WIN GATCHALIAN;',
#         ),
#         SenateBillStatus(
#             date=datetime.date(2021, 8, 25),
#             item="Senators JOEL VILLANUEVA and PIA S. CAYETANO were made co-authors;",
#         ),
#         SenateBillStatus(
#             date=datetime.date(2021, 8, 25),
#             item="Letter from Senator GRACE POE conveying her intention to be made co-author of SBN-2332, received by LBIS;",
#         ),
#         SenateBillStatus(
#             date=datetime.date(2021, 9, 20),
#             item='Interpellation/Remarks of Senator(s) RISA HONTIVEROS, PIA S. CAYETANO, JUAN MIGUEL "MIGZ" F. ZUBIRI, PANFILO "PING" M. LACSON, VICENTE C. SOTTO III, FRANKLIN M. DRILON, FRANCIS "KIKO" N. PANGILINAN and SONNY ANGARA;',
#         ),
#         SenateBillStatus(
#             date=datetime.date(2021, 9, 21), item="Period of interpellation closed;"
#         ),
#         SenateBillStatus(
#             date=datetime.date(2021, 9, 21), item="Period of individual amendments;"
#         ),
#         SenateBillStatus(
#             date=datetime.date(2021, 9, 21),
#             item="Period of individual amendments closed;",
#         ),
#         SenateBillStatus(
#             date=datetime.date(2021, 9, 21),
#             item="Approved on Second Reading with Amendments;",
#         ),
#         SenateBillStatus(
#             date=datetime.date(2021, 9, 22),
#             item="Printed copies were electronically distributed to the Senators;",
#         ),
#         SenateBillStatus(
#             date=datetime.date(2021, 9, 27), item="Approved on Third Reading;"
#         ),
#         SenateBillStatus(
#             date=datetime.date(2021, 9, 27),
#             item='In favor:  (22) Senators SONNY ANGARA, MARIA LOURDES NANCY S. BINAY, PIA S. CAYETANO, RONALD "BATO" DELA ROSA, FRANKLIN M. DRILON, WIN GATCHALIAN, CHRISTOPHER LAWRENCE T. GO, RICHARD J. GORDON, RISA HONTIVEROS, PANFILO "PING" M. LACSON, MANUEL "LITO" M. LAPID, IMEE R. MARCOS, EMMANUEL "MANNY" D. PACQUIAO, FRANCIS "KIKO" N. PANGILINAN, GRACE POE, RALPH G. RECTO, RAMON BONG REVILLA JR., VICENTE C. SOTTO III, FRANCIS "TOL" N. TOLENTINO, JOEL VILLANUEVA, CYNTHIA A. VILLAR and JUAN MIGUEL "MIGZ" F. ZUBIRI;',
#         ),
#         SenateBillStatus(date=datetime.date(2021, 9, 27), item="Against:  (None) ;"),
#         SenateBillStatus(
#             date=datetime.date(2021, 9, 27),
#             item='Abstention:  (1) Senator AQUILINO "KOKO" III PIMENTEL;',
#         ),
#         SenateBillStatus(
#             date=datetime.date(2021, 9, 27),
#             item="Senate designated Senators Gordon, Zubiri, Angara, Lapid and Hontiveros as conferees to the conference committee on the disagreeing provisions of SBN-2332 and HBN-7836;",
#         ),
#         SenateBillStatus(
#             date=datetime.date(2021, 9, 28),
#             item="Sent to the House of Representatives requesting for concurrence;",
#         ),
#         SenateBillStatus(
#             date=datetime.date(2021, 10, 13),
#             item="Conducted COMMITTEE MEETINGS/HEARINGS;",
#         ),
#         SenateBillStatus(
#             date=datetime.date(2021, 10, 20),
#             item="Conducted COMMITTEE MEETINGS/HEARINGS;",
#         ),
#         SenateBillStatus(
#             date=datetime.date(2021, 11, 8),
#             item="House of Representatives designated Representatives Deloso-Montalla, Romualdez (Y.M.),  Escudero, Benitez, Zubiri and Fortun as conferees to the Bicameral Conference Committee on the disagreeing provisions of SBN- 2332 and HBN-7836 on September 29, 2021,",
#         ),
#         SenateBillStatus(
#             date=datetime.date(2021, 11, 8),
#             item="House of Representatives designated Representative Brosas as its additional conferee to the Bicameral Conference Committee on the disagreeing provision of HBN-7836 and SBN-2332 on September 30, 2021;",
#         ),
#         SenateBillStatus(
#             date=datetime.date(2021, 12, 14),
#             item="Conference Committee Report on the disagreeing provisions of SBN-2332 and HBN-7836 submitted to the Senate, recommending that SBN-2332, in consolidation with HBN-7836, be approved in accordance with the attached copy of the bill as reconciled and approved by the conferees;",
#         ),
#         SenateBillStatus(
#             date=datetime.date(2021, 12, 15),
#             item='Sponsorship speech on the conference committee report of Senator JUAN MIGUEL "MIGZ" F. ZUBIRI;',
#         ),
#         SenateBillStatus(
#             date=datetime.date(2021, 12, 15),
#             item="Conference Committee Report Approved by the Senate;",
#         ),
#         SenateBillStatus(
#             date=datetime.date(2022, 1, 17),
#             item="Conference Committee Report Approved by the House of Representatives on December 14, 2021;",
#         ),
#         SenateBillStatus(
#             date=datetime.date(2022, 1, 25),
#             item="Letter from Senate Secretary Myra Marie D. Villarica transmitting nine (9) enrolled copies of the consolidated version of SBN-2332 and HBN-7836, for the signature of Speaker Lord Allan Jay Q. Velasco and Secretary General Mark Llandro L. Mendoza;",
#         ),
#         SenateBillStatus(
#             date=datetime.date(2022, 2, 2),
#             item="Letter for Senate Secretary Myra Marie D. Villarica, dated January 31, 2022, returning eight (8) enrolled copies of the consolidated version of SBN-2332  and HBN-7836, which were signed by Speaker Lord Allan Jay Q. Velasco and Secretary General Mark Llandro L. Mendoza;",
#         ),
#         SenateBillStatus(
#             date=datetime.date(2022, 2, 3),
#             item="Enrolled copies of the consolidated version of SBN-2332 and HBN-7836, sent to the Office of the President  through PLLO for the signature of the President of the Philippines, His Excellency, President Rodrigo Roa Duterte;",
#         ),
#         SenateBillStatus(
#             date=datetime.date(2022, 3, 8),
#             item="Approved and signed into law, in consolidation with HBN-7836, by the President of the Philippines, His Excellency, President Rodrigo Roa Duterte on March 4, 2022 and became",
#         ),
#         SenateBillStatus(
#             date=datetime.date(2022, 3, 8), item="REPUBLIC ACT NO. 11648."
#         ),
#     ],
# )
